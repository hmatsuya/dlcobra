# %%
# !nvidia-smi
# Out:
# Wed Aug 25 09:57:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:4B:00.0  On |                  N/A |
# |  0%   49C    P8    37W / 300W |   1642MiB / 11264MiB |    ERR!      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# /bin/bash: nvcc: command not found

# %%
import os
import random
from datetime import datetime
import time
import itertools
import concurrent
from concurrent.futures import ThreadPoolExecutor
import cshogi.cli

# %%
os.chdir('..')
# os.chdir('..')

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/hmats/workspace/DeepLearningShogi'

# %%
# pip install -e .

# %%
# os.listdir('//corgi/hmatsuya/workspace/Shogi/data/dl_data/hcpe')
# os.listdir('/mnt/corgi/hmatsuya/workspace/Shogi/data/dl_data/hcpe')

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/hmats/workspace/DeepLearningShogi'

# %%
os.chdir('dlshogi')

# %%
#os.mkdir('../model')

# %%
#os.mkdir('../log')

# %% [markdown]
# ## Test critic

# %%
# resnet8_dropout
# # advantage: no value
# val_lambda: 0
# tanh
# polic_coef: 0.5

chunk_size = 38 * 20 * 1000 * 1000
activation='C:\\Anaconda3\\Scripts\\activate.bat'
test='/mnt/corgi/hmatsuya/workspace/Shogi/data/dl_data/hcpe/floodgate_teacher_uniq-test-01'

#! wsl ssh hmatsuya@corgi ls -lh /home/hmatsuya/workspace/Shogi/data/apery_teacher/

# resume = '-r ../model/state-2019'
resume = ''
teacher_dir = '/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled'
filelist = os.listdir(teacher_dir)
hcpelist = list(filter(lambda f: '.hcpe' in f, filelist))
files = []
project = "test_critic"
test_name = "result_critic01"
name = f'{test_name}'
run_id = f'{name}.{time.time()}'
i = 0
if i == 0:
    resume = ''
else:
    resume = f'-m ../model/model-{name}-{i-1} -r ../model/checkpoint-{name}-{i-1}.pth'

for file in random.sample(hcpelist, len(hcpelist)):
    
    files.append(file)
    if len(files) < 10:
        continue
    
    teacher=' '.join([f'{teacher_dir}/{f}' for f in files])
    
    model=f'../model/model-{name}-{i}'
    checkpoint=f'../model/checkpoint-{name}-{i}.pth'
    log=f'../log/{name}.txt'
    ! python -u train.py {teacher} {test} --model {model} --checkpoint {checkpoint} {resume} --use_result_critic --critic_lambda 0.1 --val_lambda 0.3 --lr 0.001 --weight_decay 0.00001 --use_average --use_evalfix --use_swa --log {log} --use_amp --project {project} --run_id {run_id}

    files.clear()
    resume = f'-r {checkpoint} -m {model}'
    i += 1
# Out:
# 2021/08/25 09:57:58	INFO	network resnet10_swish
# 2021/08/25 09:57:58	INFO	batchsize=1024
# 2021/08/25 09:57:58	INFO	lr=0.001
# 2021/08/25 09:57:58	INFO	weight_decay=1e-05
# 2021/08/25 09:57:58	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_095805-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/25 09:58:11	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/25 09:58:11	INFO	use amp
# 2021/08/25 09:58:11	INFO	use evalfix
# 2021/08/25 09:58:11	INFO	temperature=1.0
# 2021/08/25 09:58:11	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/25 09:58:11	INFO	Reading training data
# 2021/08/25 09:58:16	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_14622366825055521639.hcpe, a=520.4986092088426
# 2021/08/25 09:58:23	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6315666480270484901.hcpe, a=503.02922296415113
# 2021/08/25 09:58:30	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11775493241625134003.hcpe, a=498.5518842014117
# 2021/08/25 09:58:37	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_3718630813030921688.hcpe, a=502.50238552397286
# 2021/08/25 09:58:44	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17611715091927274531.hcpe, a=518.6599879949015
# 2021/08/25 09:58:51	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17584451196576796483.hcpe, a=498.03896944030964
# 2021/08/25 09:58:58	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11628480669592412417.hcpe, a=479.1677606450428
# 2021/08/25 09:59:05	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_7595098186627026995.hcpe, a=517.643522013167
# 2021/08/25 09:59:13	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_2794288503443058737.hcpe, a=513.8970894112126
# 2021/08/25 09:59:21	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11874693769347130446.hcpe, a=494.9405378386296
# 2021/08/25 09:59:24	INFO	Reading test data
# 2021/08/25 09:59:32	INFO	train position num before preprocessing = 10008898
# 2021/08/25 09:59:32	INFO	train position num = 10008825
# 2021/08/25 09:59:32	INFO	test position num = 2414974
# 2021/08/25 09:59:34	INFO	epoch = 1, steps = 1, train loss = 8.8716612, 0.6914168, 0.6913760, 9.5630655, test loss = 7.6883221, 0.6927493, 0.6924658, 8.3809872, test accuracy = 0.0000000, 0.5185547
# 2021/08/25 10:03:59	INFO	epoch = 1, steps = 1000, train loss = 4.1029420, 0.4328313, 0.4380092, 4.5373267, test loss = 3.1212337, 0.6313946, 0.6689479, 3.7638946, test accuracy = 0.2558594, 0.6201172
# 2021/08/25 10:08:29	INFO	epoch = 1, steps = 2000, train loss = 3.0319659, 0.3517049, 0.3584652, 3.3856988, test loss = 2.6837168, 0.5973416, 0.6416395, 3.2943478, test accuracy = 0.3056641, 0.6621094
# 2021/08/25 10:13:01	INFO	epoch = 1, steps = 3000, train loss = 2.8113910, 0.3333561, 0.3409684, 3.1470308, test loss = 2.6534133, 0.6358304, 0.6591442, 3.2962377, test accuracy = 0.3281250, 0.6191406
# 2021/08/25 10:17:34	INFO	epoch = 1, steps = 4000, train loss = 2.6909528, 0.3251676, 0.3323087, 3.0182628, test loss = 2.5813665, 0.6263168, 0.6557912, 3.2165258, test accuracy = 0.3164062, 0.6396484
# 2021/08/25 10:22:07	INFO	epoch = 1, steps = 5000, train loss = 2.6085134, 0.3172401, 0.3255165, 2.9282364, test loss = 2.6010058, 0.5911282, 0.6496477, 3.2096899, test accuracy = 0.3222656, 0.6728516
# 2021/08/25 10:26:44	INFO	epoch = 1, steps = 6000, train loss = 2.5491645, 0.3130115, 0.3219295, 2.8648514, test loss = 2.4429455, 0.5741729, 0.6310443, 3.0341799, test accuracy = 0.3183594, 0.6699219
# 2021/08/25 10:31:18	INFO	epoch = 1, steps = 7000, train loss = 2.5005290, 0.3095101, 0.3180034, 2.8125871, test loss = 2.4248395, 0.6015518, 0.6570518, 3.0430412, test accuracy = 0.3359375, 0.6533203
# 2021/08/25 10:35:56	INFO	epoch = 1, steps = 8000, train loss = 2.4680080, 0.3062563, 0.3157501, 2.7771124, test loss = 2.4277682, 0.6163064, 0.6599315, 3.0571623, test accuracy = 0.3369141, 0.6503906
# 2021/08/25 10:40:32	INFO	epoch = 1, steps = 9000, train loss = 2.4380059, 0.3042707, 0.3146334, 2.7453854, test loss = 2.4292321, 0.5988252, 0.6476649, 3.0427094, test accuracy = 0.3378906, 0.6513672
# 2021/08/25 10:48:54	INFO	epoch = 1, steps = 9774, train loss avr = 2.7696424, 0.3302122, 0.3384235, 3.1023180, test loss = 2.3807718, 0.5875476, 0.6397766, 2.9839882, test accuracy = 0.3415790, 0.6604789, test entropy = 2.2113886, 0.5730231
# 2021/08/25 10:48:54	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-0.pth
# 2021/08/25 10:48:55	INFO	Updating batch normalization
# 2021/08/25 11:08:05	INFO	epoch = 1, steps = 9774, swa test loss = 2.3882518, 0.5842286, 0.6343125, 2.9875056, swa test accuracy = 0.3430629, 0.6635734, swa test entropy = 2.2846184, 0.5778666
# 2021/08/25 11:08:05	INFO	Saving the model to ../model/model-reslut_critic01-0
#
# wandb: Waiting for W&B process to finish, PID 34362
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_095805-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_095805-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 2.43801
# wandb:           train/loss_result 0.30427
# wandb:            train/loss_value 0.31463
# wandb:              train/loss_sum 2.74539
# wandb:           valid/loss_policy 2.42923
# wandb:           valid/loss_result 0.59883
# wandb:            valid/loss_value 0.64766
# wandb:              valid/loss_sum 3.04271
# wandb:        valid_acc/acc_policy 0.33789
# wandb:        valid_acc/acc_result 0.65137
# wandb:                    _runtime 4201
# wandb:                  _timestamp 1629857286
# wandb:                       _step 9000
# wandb: Run history:
# wandb:      train/loss_policy █▃▂▁▁▁▁▁▁▁
# wandb:      train/loss_result █▃▂▂▁▁▁▁▁▁
# wandb:       train/loss_value █▃▂▁▁▁▁▁▁▁
# wandb:         train/loss_sum █▃▂▁▁▁▁▁▁▁
# wandb:      valid/loss_policy █▂▁▁▁▁▁▁▁▁
# wandb:      valid/loss_result █▄▂▅▄▂▁▃▃▂
# wandb:       valid/loss_value █▅▂▄▄▃▁▄▄▃
# wandb:         valid/loss_sum █▂▁▁▁▁▁▁▁▁
# wandb:   valid_acc/acc_policy ▁▆▇███████
# wandb:   valid_acc/acc_result ▁▆█▆▆██▇▇▇
# wandb:               _runtime ▁▁▂▂▃▃▄▄▅█
# wandb:             _timestamp ▁▁▂▂▃▃▄▄▅█
# wandb:                  _step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 315 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/25 11:08:21	INFO	network resnet10_swish
# 2021/08/25 11:08:21	INFO	batchsize=1024
# 2021/08/25 11:08:21	INFO	lr=0.001
# 2021/08/25 11:08:21	INFO	weight_decay=1e-05
# 2021/08/25 11:08:21	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_110832-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/25 11:08:38	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/25 11:08:38	INFO	use amp
# 2021/08/25 11:08:38	INFO	use evalfix
# 2021/08/25 11:08:38	INFO	temperature=1.0
# 2021/08/25 11:08:38	INFO	Loading the model from ../model/model-reslut_critic01-0
# 2021/08/25 11:08:39	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-0.pth
# 2021/08/25 11:08:39	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/25 11:08:39	INFO	Reading training data
# 2021/08/25 11:08:44	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6870867357469892784.hcpe, a=521.5552015760626
# 2021/08/25 11:08:51	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11938991827029849797.hcpe, a=510.3293218586471
# 2021/08/25 11:08:59	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_10212759931665321151.hcpe, a=505.18094692279385
# 2021/08/25 11:09:06	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_14153889718678814310.hcpe, a=493.9045850730334
# 2021/08/25 11:09:14	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11902507917387461027.hcpe, a=496.40966944310435
# 2021/08/25 11:09:22	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_10851901136355681535.hcpe, a=499.9921493846253
# 2021/08/25 11:09:30	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_4046542324089157466.hcpe, a=508.7137856784347
# 2021/08/25 11:09:37	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_5182609235957979648.hcpe, a=514.2783772115254
# 2021/08/25 11:09:46	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6244294819029180808.hcpe, a=510.32984663966386
# 2021/08/25 11:09:56	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1899110332338198150.hcpe, a=522.2133187896546
# 2021/08/25 11:10:00	INFO	Reading test data
# 2021/08/25 11:10:09	INFO	train position num before preprocessing = 10007649
# 2021/08/25 11:10:09	INFO	train position num = 10007561
# 2021/08/25 11:10:09	INFO	test position num = 2414974
# 2021/08/25 11:11:12	INFO	epoch = 2, steps = 10000, train loss = 2.4043176, 0.3089420, 0.3132066, 2.7145390, test loss = 2.4069934, 0.5952721, 0.6525900, 3.0194607, test accuracy = 0.3388672, 0.6728516
# 2021/08/25 11:15:46	INFO	epoch = 2, steps = 11000, train loss = 2.3831135, 0.3054956, 0.3121389, 2.6906021, test loss = 2.3514266, 0.6019145, 0.6310410, 2.9620790, test accuracy = 0.3486328, 0.6357422
# 2021/08/25 11:20:21	INFO	epoch = 2, steps = 12000, train loss = 2.3634719, 0.3028037, 0.3104330, 2.6685644, test loss = 2.3623652, 0.5658525, 0.6239971, 2.9456613, test accuracy = 0.3486328, 0.6884766
# 2021/08/25 11:24:52	INFO	epoch = 2, steps = 13000, train loss = 2.3436974, 0.3009499, 0.3092283, 2.6471309, test loss = 2.2401257, 0.5964402, 0.6373232, 2.8488307, test accuracy = 0.3867188, 0.6523438
# 2021/08/25 11:29:31	INFO	epoch = 2, steps = 14000, train loss = 2.3249424, 0.2996953, 0.3084766, 2.6272721, test loss = 2.4007933, 0.5955151, 0.6368826, 3.0087185, test accuracy = 0.3535156, 0.6572266
# 2021/08/25 11:34:18	INFO	epoch = 2, steps = 15000, train loss = 2.3121118, 0.2969263, 0.3069639, 2.6120494, test loss = 2.3189578, 0.5957620, 0.6422948, 2.9286797, test accuracy = 0.3486328, 0.6552734
# 2021/08/25 11:38:52	INFO	epoch = 2, steps = 16000, train loss = 2.2962275, 0.2965668, 0.3062565, 2.5957012, test loss = 2.2976465, 0.5646715, 0.6213543, 2.8793230, test accuracy = 0.3593750, 0.6708984
# 2021/08/25 11:43:32	INFO	epoch = 2, steps = 17000, train loss = 2.2841961, 0.2949685, 0.3053440, 2.5822773, test loss = 2.3635228, 0.5830621, 0.6224698, 2.9584072, test accuracy = 0.3339844, 0.6347656
# 2021/08/25 11:48:09	INFO	epoch = 2, steps = 18000, train loss = 2.2690821, 0.2947809, 0.3053610, 2.5670371, test loss = 2.2482691, 0.5691833, 0.6302363, 2.8357682, test accuracy = 0.3837891, 0.6699219
# 2021/08/25 11:52:51	INFO	epoch = 2, steps = 19000, train loss = 2.2553130, 0.2935864, 0.3043680, 2.5521339, test loss = 2.2504549, 0.5680323, 0.6272860, 2.8362632, test accuracy = 0.3535156, 0.6894531
# 2021/08/25 12:00:27	INFO	epoch = 2, steps = 19547, train loss avr = 2.3130063, 0.2983819, 0.3075366, 2.6141346, test loss = 2.2735650, 0.5777956, 0.6284951, 2.8665705, test accuracy = 0.3575370, 0.6674072, test entropy = 2.0290907, 0.5688715
# 2021/08/25 12:00:27	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-1.pth
# 2021/08/25 12:00:27	INFO	Updating batch normalization
# 2021/08/25 12:20:32	INFO	epoch = 2, steps = 19547, swa test loss = 2.2241324, 0.5698647, 0.6215826, 2.8095125, swa test accuracy = 0.3658349, 0.6746734, swa test entropy = 2.0955932, 0.5772655
# 2021/08/25 12:20:32	INFO	Saving the model to ../model/model-reslut_critic01-1
#
# wandb: Waiting for W&B process to finish, PID 34949
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_110832-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_110832-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 2.25531
# wandb:           train/loss_result 0.29359
# wandb:            train/loss_value 0.30437
# wandb:              train/loss_sum 2.55213
# wandb:           valid/loss_policy 2.25045
# wandb:           valid/loss_result 0.56803
# wandb:            valid/loss_value 0.62729
# wandb:              valid/loss_sum 2.83626
# wandb:        valid_acc/acc_policy 0.35352
# wandb:        valid_acc/acc_result 0.68945
# wandb:                    _runtime 4321
# wandb:                  _timestamp 1629861633
# wandb:                       _step 19000
# wandb: Run history:
# wandb:      train/loss_policy █▇▆▅▄▄▃▂▂▁
# wandb:      train/loss_result █▆▅▄▄▃▂▂▂▁
# wandb:       train/loss_value █▇▆▅▄▃▂▂▂▁
# wandb:         train/loss_sum █▇▆▅▄▄▃▂▂▁
# wandb:      valid/loss_policy █▆▆▁█▄▃▆▁▁
# wandb:      valid/loss_result ▇█▁▇▇▇▁▄▂▂
# wandb:       valid/loss_value █▃▂▅▄▆▁▁▃▂
# wandb:         valid/loss_sum █▆▅▁█▅▃▆▁▁
# wandb:   valid_acc/acc_policy ▂▃▃█▄▃▄▁█▄
# wandb:   valid_acc/acc_result ▆▁█▃▄▄▆▁▅█
# wandb:               _runtime ▁▁▂▂▃▃▄▄▅█
# wandb:             _timestamp ▁▁▂▂▃▃▄▄▅█
# wandb:                  _step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 304 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/25 12:20:49	INFO	network resnet10_swish
# 2021/08/25 12:20:49	INFO	batchsize=1024
# 2021/08/25 12:20:49	INFO	lr=0.001
# 2021/08/25 12:20:49	INFO	weight_decay=1e-05
# 2021/08/25 12:20:49	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_122100-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/25 12:21:07	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/25 12:21:07	INFO	use amp
# 2021/08/25 12:21:07	INFO	use evalfix
# 2021/08/25 12:21:07	INFO	temperature=1.0
# 2021/08/25 12:21:07	INFO	Loading the model from ../model/model-reslut_critic01-1
# 2021/08/25 12:21:08	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-1.pth
# 2021/08/25 12:21:08	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/25 12:21:08	INFO	Reading training data
# 2021/08/25 12:21:13	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_12872563178535626760.hcpe, a=493.6333643131245
# 2021/08/25 12:21:22	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_15844194399671942922.hcpe, a=513.8294811960344
# 2021/08/25 12:21:31	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_5636128563152613209.hcpe, a=523.5274789891715
# 2021/08/25 12:21:40	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17162493174601601301.hcpe, a=522.0043732516204
# 2021/08/25 12:21:49	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17503865101848919454.hcpe, a=504.69784616347323
# 2021/08/25 12:21:58	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_8787203444831731396.hcpe, a=521.7518534845613
# 2021/08/25 12:22:06	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_8629855243186910634.hcpe, a=518.2803236198943
# 2021/08/25 12:22:14	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_13974255552529668740.hcpe, a=526.2497886756502
# 2021/08/25 12:22:24	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_13710148564121797090.hcpe, a=499.3988193815219
# 2021/08/25 12:22:33	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_2993097732172579029.hcpe, a=502.74213573611183
# 2021/08/25 12:22:37	INFO	Reading test data
# 2021/08/25 12:22:47	INFO	train position num before preprocessing = 10008223
# 2021/08/25 12:22:47	INFO	train position num = 10008114
# 2021/08/25 12:22:47	INFO	test position num = 2414974
# 2021/08/25 12:24:57	INFO	epoch = 3, steps = 20000, train loss = 2.2490903, 0.2979341, 0.3059122, 2.5494178, test loss = 2.2646735, 0.5923119, 0.6277479, 2.8676162, test accuracy = 0.3535156, 0.6406250
# 2021/08/25 12:29:50	INFO	epoch = 3, steps = 21000, train loss = 2.2452873, 0.2971828, 0.3055590, 2.5449829, test loss = 2.2061729, 0.5665343, 0.6260251, 2.7905545, test accuracy = 0.3603516, 0.6708984
# 2021/08/25 12:34:32	INFO	epoch = 3, steps = 22000, train loss = 2.2286209, 0.2951116, 0.3043636, 2.5265081, test loss = 2.2280889, 0.5663447, 0.6206686, 2.8107309, test accuracy = 0.3593750, 0.6806641
# 2021/08/25 12:38:59	INFO	epoch = 3, steps = 23000, train loss = 2.2202838, 0.2941641, 0.3045895, 2.5175755, test loss = 2.1871285, 0.5886896, 0.6283280, 2.7877100, test accuracy = 0.3574219, 0.6406250
# 2021/08/25 12:43:24	INFO	epoch = 3, steps = 24000, train loss = 2.2136017, 0.2928703, 0.3035978, 2.5096902, test loss = 2.1721640, 0.5582983, 0.6087406, 2.7455950, test accuracy = 0.3720703, 0.6826172
# 2021/08/25 12:47:54	INFO	epoch = 3, steps = 25000, train loss = 2.2038561, 0.2926201, 0.3034612, 2.4997286, test loss = 2.2363853, 0.5743225, 0.6274961, 2.8266599, test accuracy = 0.3701172, 0.6728516
# 2021/08/25 12:52:21	INFO	epoch = 3, steps = 26000, train loss = 2.1950139, 0.2917939, 0.3028220, 2.4901162, test loss = 2.2146459, 0.5771969, 0.6389298, 2.8103628, test accuracy = 0.3750000, 0.6826172
# 2021/08/25 12:57:00	INFO	epoch = 3, steps = 27000, train loss = 2.1801477, 0.2905255, 0.3024082, 2.4742380, test loss = 2.1723936, 0.5452762, 0.6121926, 2.7377446, test accuracy = 0.3798828, 0.6923828
# 2021/08/25 13:01:31	INFO	epoch = 3, steps = 28000, train loss = 2.1818131, 0.2894287, 0.3016718, 2.4749147, test loss = 2.1603589, 0.5722117, 0.6273832, 2.7491221, test accuracy = 0.3759766, 0.6601562
# 2021/08/25 13:06:09	INFO	epoch = 3, steps = 29000, train loss = 2.1702092, 0.2891894, 0.3025258, 2.4633996, test loss = 2.2395205, 0.5451189, 0.6081563, 2.8035507, test accuracy = 0.3525391, 0.6816406
# 2021/08/25 13:12:33	INFO	epoch = 3, steps = 29320, train loss avr = 2.2053681, 0.2926724, 0.3034944, 2.5012871, test loss = 2.1836049, 0.5709521, 0.6288226, 2.7719182, test accuracy = 0.3682415, 0.6716435, test entropy = 2.0352425, 0.5671137
# 2021/08/25 13:12:33	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-2.pth
# 2021/08/25 13:12:33	INFO	Updating batch normalization
# 2021/08/25 13:31:32	INFO	epoch = 3, steps = 29320, swa test loss = 2.1497307, 0.5641615, 0.6171642, 2.7297930, swa test accuracy = 0.3769614, 0.6792763, swa test entropy = 2.0181170, 0.5763488
# 2021/08/25 13:31:32	INFO	Saving the model to ../model/model-reslut_critic01-2
#
# wandb: Waiting for W&B process to finish, PID 35505
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_122100-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_122100-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 2.17021
# wandb:           train/loss_result 0.28919
# wandb:            train/loss_value 0.30253
# wandb:              train/loss_sum 2.4634
# wandb:           valid/loss_policy 2.23952
# wandb:           valid/loss_result 0.54512
# wandb:            valid/loss_value 0.60816
# wandb:              valid/loss_sum 2.80355
# wandb:        valid_acc/acc_policy 0.35254
# wandb:        valid_acc/acc_result 0.68164
# wandb:                    _runtime 4232
# wandb:                  _timestamp 1629865893
# wandb:                       _step 29000
# wandb: Run history:
# wandb:      train/loss_policy ██▆▅▅▄▃▂▂▁
# wandb:      train/loss_result █▇▆▅▄▄▃▂▁▁
# wandb:       train/loss_value █▇▅▆▄▄▃▂▁▂
# wandb:         train/loss_sum ██▆▅▅▄▃▂▂▁
# wandb:      valid/loss_policy █▄▆▃▂▆▅▂▁▆
# wandb:      valid/loss_result █▄▄▇▃▅▆▁▅▁
# wandb:       valid/loss_value ▅▅▄▆▁▅█▂▅▁
# wandb:         valid/loss_sum █▄▅▄▁▆▅▁▂▅
# wandb:   valid_acc/acc_policy ▁▃▃▂▆▅▇█▇▁
# wandb:   valid_acc/acc_result ▁▅▆▁▇▅▇█▄▇
# wandb:               _runtime ▁▂▂▃▃▄▄▅▅█
# wandb:             _timestamp ▁▂▂▃▃▄▄▅▅█
# wandb:                  _step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 304 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/25 13:31:48	INFO	network resnet10_swish
# 2021/08/25 13:31:48	INFO	batchsize=1024
# 2021/08/25 13:31:48	INFO	lr=0.001
# 2021/08/25 13:31:48	INFO	weight_decay=1e-05
# 2021/08/25 13:31:48	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_133202-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/25 13:32:08	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/25 13:32:09	INFO	use amp
# 2021/08/25 13:32:09	INFO	use evalfix
# 2021/08/25 13:32:09	INFO	temperature=1.0
# 2021/08/25 13:32:09	INFO	Loading the model from ../model/model-reslut_critic01-2
# 2021/08/25 13:32:09	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-2.pth
# 2021/08/25 13:32:09	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/25 13:32:09	INFO	Reading training data
# 2021/08/25 13:32:14	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11074647812308438555.hcpe, a=500.96755936511323
# 2021/08/25 13:32:21	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_12527282462227445404.hcpe, a=508.1488269760469
# 2021/08/25 13:32:28	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6839092951411212475.hcpe, a=540.6625164745193
# 2021/08/25 13:32:36	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_12199301368645901196.hcpe, a=510.02538107649156
# 2021/08/25 13:32:44	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1550589308357295315.hcpe, a=508.2899584044068
# 2021/08/25 13:32:51	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_4347237127923684954.hcpe, a=515.6182718936167
# 2021/08/25 13:32:59	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_12446144673142010795.hcpe, a=522.2279278478023
# 2021/08/25 13:33:07	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_14091270187527350358.hcpe, a=515.6526760650929
# 2021/08/25 13:33:15	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_16118423324486518528.hcpe, a=493.7274987244548
# 2021/08/25 13:33:24	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1570099497025876797.hcpe, a=517.3680106936615
# 2021/08/25 13:33:28	INFO	Reading test data
# 2021/08/25 13:33:37	INFO	train position num before preprocessing = 10008477
# 2021/08/25 13:33:37	INFO	train position num = 10008428
# 2021/08/25 13:33:37	INFO	test position num = 2414974
# 2021/08/25 13:36:49	INFO	epoch = 4, steps = 30000, train loss = 2.1640729, 0.2945875, 0.3023155, 2.4609788, test loss = 2.1579881, 0.5671828, 0.6181626, 2.7404647, test accuracy = 0.3886719, 0.6787109
# 2021/08/25 13:41:37	INFO	epoch = 4, steps = 31000, train loss = 2.1590581, 0.2924921, 0.3021028, 2.4544335, test loss = 2.1860919, 0.5664115, 0.6236801, 2.7696841, test accuracy = 0.3408203, 0.6826172
# 2021/08/25 13:46:19	INFO	epoch = 4, steps = 32000, train loss = 2.1529710, 0.2918416, 0.3014678, 2.4477004, test loss = 2.1282177, 0.5813417, 0.6286924, 2.7237647, test accuracy = 0.3857422, 0.6650391
# 2021/08/25 13:50:43	INFO	epoch = 4, steps = 33000, train loss = 2.1500155, 0.2920250, 0.3021319, 2.4450726, test loss = 2.1998639, 0.5833636, 0.6421217, 2.8008549, test accuracy = 0.3720703, 0.6708984
# 2021/08/25 13:55:09	INFO	epoch = 4, steps = 34000, train loss = 2.1408331, 0.2907283, 0.3011792, 2.4346967, test loss = 2.2134776, 0.5714132, 0.6182581, 2.7989445, test accuracy = 0.3710938, 0.6923828
# 2021/08/25 13:59:40	INFO	epoch = 4, steps = 35000, train loss = 2.1363128, 0.2891794, 0.3005674, 2.4289086, test loss = 2.1911631, 0.5624527, 0.6171231, 2.7700169, test accuracy = 0.3525391, 0.6689453
# 2021/08/25 14:04:27	INFO	epoch = 4, steps = 36000, train loss = 2.1297325, 0.2893247, 0.3007226, 2.4224766, test loss = 2.1552002, 0.5928069, 0.6249291, 2.7576437, test accuracy = 0.3818359, 0.6376953
# 2021/08/25 14:09:12	INFO	epoch = 4, steps = 37000, train loss = 2.1244789, 0.2892022, 0.3006100, 2.4171035, test loss = 2.1518321, 0.5754715, 0.6165042, 2.7396135, test accuracy = 0.3583984, 0.6718750
# 2021/08/25 14:13:49	INFO	epoch = 4, steps = 38000, train loss = 2.1187644, 0.2883222, 0.3007538, 2.4108160, test loss = 2.1100864, 0.5497142, 0.6070215, 2.6769929, test accuracy = 0.3808594, 0.7187500
# 2021/08/25 14:18:23	INFO	epoch = 4, steps = 39000, train loss = 2.1150522, 0.2871820, 0.3001957, 2.4061383, test loss = 2.0803199, 0.5686436, 0.6158496, 2.6631253, test accuracy = 0.3779297, 0.6806641
# 2021/08/25 14:23:44	INFO	epoch = 4, steps = 39093, train loss avr = 2.1381292, 0.2903281, 0.3011548, 2.4317053, test loss = 2.1448886, 0.5638958, 0.6153354, 2.7242162, test accuracy = 0.3756448, 0.6784803, test entropy = 1.9664327, 0.5727914
# 2021/08/25 14:23:44	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-3.pth
# 2021/08/25 14:23:45	INFO	Updating batch normalization
# 2021/08/25 14:42:59	INFO	epoch = 4, steps = 39093, swa test loss = 2.1044651, 0.5592758, 0.6141734, 2.6802102, swa test accuracy = 0.3841958, 0.6834285, swa test entropy = 1.9681177, 0.5764539
# 2021/08/25 14:42:59	INFO	Saving the model to ../model/model-reslut_critic01-3
#
# wandb: Waiting for W&B process to finish, PID 36062
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_133202-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_133202-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 2.11505
# wandb:           train/loss_result 0.28718
# wandb:            train/loss_value 0.3002
# wandb:              train/loss_sum 2.40614
# wandb:           valid/loss_policy 2.08032
# wandb:           valid/loss_result 0.56864
# wandb:            valid/loss_value 0.61585
# wandb:              valid/loss_sum 2.66313
# wandb:        valid_acc/acc_policy 0.37793
# wandb:        valid_acc/acc_result 0.68066
# wandb:                    _runtime 4259
# wandb:                  _timestamp 1629870181
# wandb:                       _step 39000
# wandb: Run history:
# wandb:      train/loss_policy █▇▆▆▅▄▃▂▂▁
# wandb:      train/loss_result █▆▅▆▄▃▃▃▂▁
# wandb:       train/loss_value █▇▅▇▄▂▃▂▃▁
# wandb:         train/loss_sum █▇▆▆▅▄▃▂▂▁
# wandb:      valid/loss_policy ▅▇▄▇█▇▅▅▃▁
# wandb:      valid/loss_result ▄▄▆▆▅▃█▅▁▄
# wandb:       valid/loss_value ▃▄▅█▃▃▅▃▁▃
# wandb:         valid/loss_sum ▅▆▄██▆▆▅▂▁
# wandb:   valid_acc/acc_policy █▁█▆▅▃▇▄▇▆
# wandb:   valid_acc/acc_result ▅▅▃▄▆▄▁▄█▅
# wandb:               _runtime ▁▂▂▃▃▄▄▅▅█
# wandb:             _timestamp ▁▂▂▃▃▄▄▅▅█
# wandb:                  _step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 299 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/25 14:43:17	INFO	network resnet10_swish
# 2021/08/25 14:43:17	INFO	batchsize=1024
# 2021/08/25 14:43:17	INFO	lr=0.001
# 2021/08/25 14:43:17	INFO	weight_decay=1e-05
# 2021/08/25 14:43:17	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_144332-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/25 14:43:38	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/25 14:43:38	INFO	use amp
# 2021/08/25 14:43:38	INFO	use evalfix
# 2021/08/25 14:43:38	INFO	temperature=1.0
# 2021/08/25 14:43:38	INFO	Loading the model from ../model/model-reslut_critic01-3
# 2021/08/25 14:43:39	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-3.pth
# 2021/08/25 14:43:39	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/25 14:43:39	INFO	Reading training data
# 2021/08/25 14:43:43	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_4115379733335557791.hcpe, a=512.5360468261658
# 2021/08/25 14:43:51	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_4658385948636296448.hcpe, a=507.7481722067934
# 2021/08/25 14:43:59	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_18444005528176295099.hcpe, a=486.22634635523104
# 2021/08/25 14:44:06	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_9999355447769669194.hcpe, a=488.1282381332222
# 2021/08/25 14:44:15	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11587516217019279835.hcpe, a=517.9251493136601
# 2021/08/25 14:44:23	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_11359456525263144743.hcpe, a=501.213433127415
# 2021/08/25 14:44:30	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1753584158893375162.hcpe, a=491.244970676246
# 2021/08/25 14:44:39	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_2756129141380964008.hcpe, a=505.9459757931389
# 2021/08/25 14:44:48	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17122538381347141112.hcpe, a=492.08492228380396
# 2021/08/25 14:44:57	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_16894930388060065760.hcpe, a=509.8006802985433
# 2021/08/25 14:45:01	INFO	Reading test data
# 2021/08/25 14:45:10	INFO	train position num before preprocessing = 10007484
# 2021/08/25 14:45:10	INFO	train position num = 10007437
# 2021/08/25 14:45:10	INFO	test position num = 2414974
# 2021/08/25 14:49:19	INFO	epoch = 5, steps = 40000, train loss = 2.1145943, 0.2872511, 0.2960402, 2.4044822, test loss = 2.0696669, 0.5702262, 0.6188644, 2.6544847, test accuracy = 0.3896484, 0.6728516
# 2021/08/25 14:53:58	INFO	epoch = 5, steps = 41000, train loss = 2.1096922, 0.2864821, 0.2965789, 2.3992033, test loss = 2.1508224, 0.5788550, 0.6231111, 2.7429543, test accuracy = 0.3740234, 0.6660156
# 2021/08/25 14:58:42	INFO	epoch = 5, steps = 42000, train loss = 2.1018103, 0.2851311, 0.2959929, 2.3901999, test loss = 2.1000814, 0.5766518, 0.6268663, 2.6917977, test accuracy = 0.3935547, 0.6679688
# 2021/08/25 15:03:27	INFO	epoch = 5, steps = 43000, train loss = 2.1024022, 0.2830877, 0.2949383, 2.3890451, test loss = 2.1187563, 0.5555013, 0.6101074, 2.6906393, test accuracy = 0.3789062, 0.6738281
# 2021/08/25 15:08:07	INFO	epoch = 5, steps = 44000, train loss = 2.0977801, 0.2841716, 0.2955126, 2.3853540, test loss = 2.1729174, 0.5407428, 0.6056018, 2.7331181, test accuracy = 0.3525391, 0.7050781
# 2021/08/25 15:12:50	INFO	epoch = 5, steps = 45000, train loss = 2.0886166, 0.2831266, 0.2951439, 2.3753484, test loss = 2.1404080, 0.5514774, 0.6169241, 2.7115197, test accuracy = 0.3740234, 0.6982422
# 2021/08/25 15:17:31	INFO	epoch = 5, steps = 46000, train loss = 2.0875114, 0.2826536, 0.2948057, 2.3738106, test loss = 2.0898802, 0.5738645, 0.6204158, 2.6777098, test accuracy = 0.3828125, 0.6660156
# 2021/08/25 15:22:11	INFO	epoch = 5, steps = 47000, train loss = 2.0857901, 0.2820186, 0.2947353, 2.3716237, test loss = 2.2102814, 0.5689653, 0.6203575, 2.7946644, test accuracy = 0.3691406, 0.6699219
# 2021/08/25 15:26:40	INFO	epoch = 5, steps = 48000, train loss = 2.0835721, 0.2809365, 0.2944275, 2.3685559, test loss = 2.0748429, 0.5849299, 0.6199005, 2.6702640, test accuracy = 0.4003906, 0.6425781
# 2021/08/25 15:35:12	INFO	epoch = 5, steps = 48865, train loss avr = 2.0948263, 0.2834497, 0.2952177, 2.3818064, test loss = 2.1099391, 0.5686619, 0.6297993, 2.6969423, test accuracy = 0.3807111, 0.6736239, test entropy = 1.9167919, 0.5691860
# 2021/08/25 15:35:12	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-4.pth
# 2021/08/25 15:35:13	INFO	Updating batch normalization
# 2021/08/25 15:54:30	INFO	epoch = 5, steps = 48865, swa test loss = 2.0713958, 0.5569549, 0.6125801, 2.6450383, swa test accuracy = 0.3891850, 0.6848341, swa test entropy = 1.9349039, 0.5741965
# 2021/08/25 15:54:30	INFO	Saving the model to ../model/model-reslut_critic01-4
#
# wandb: Waiting for W&B process to finish, PID 36615
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_144332-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_144332-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 2.08357
# wandb:           train/loss_result 0.28094
# wandb:            train/loss_value 0.29443
# wandb:              train/loss_sum 2.36856
# wandb:           valid/loss_policy 2.07484
# wandb:           valid/loss_result 0.58493
# wandb:            valid/loss_value 0.6199
# wandb:              valid/loss_sum 2.67026
# wandb:        valid_acc/acc_policy 0.40039
# wandb:        valid_acc/acc_result 0.64258
# wandb:                    _runtime 4259
# wandb:                  _timestamp 1629874471
# wandb:                       _step 48000
# wandb: Run history:
# wandb:      train/loss_policy █▇▅▅▄▂▂▂▁
# wandb:      train/loss_result █▇▆▃▅▃▃▂▁
# wandb:       train/loss_value ▆█▆▃▅▃▂▂▁
# wandb:         train/loss_sum █▇▅▅▄▂▂▂▁
# wandb:      valid/loss_policy ▁▅▃▃▆▅▂█▁
# wandb:      valid/loss_result ▆▇▇▃▁▃▆▅█
# wandb:       valid/loss_value ▅▇█▂▁▅▆▆▆
# wandb:         valid/loss_sum ▁▅▃▃▅▄▂█▂
# wandb:   valid_acc/acc_policy ▆▄▇▅▁▄▅▃█
# wandb:   valid_acc/acc_result ▄▄▄▅█▇▄▄▁
# wandb:               _runtime ▁▂▂▃▃▄▄▅█
# wandb:             _timestamp ▁▂▂▃▃▄▄▅█
# wandb:                  _step ▁▂▃▄▅▅▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 272 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/25 15:54:46	INFO	network resnet10_swish
# 2021/08/25 15:54:46	INFO	batchsize=1024
# 2021/08/25 15:54:46	INFO	lr=0.001
# 2021/08/25 15:54:46	INFO	weight_decay=1e-05
# 2021/08/25 15:54:46	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_155500-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/25 15:55:07	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/25 15:55:07	INFO	use amp
# 2021/08/25 15:55:07	INFO	use evalfix
# 2021/08/25 15:55:07	INFO	temperature=1.0
# 2021/08/25 15:55:07	INFO	Loading the model from ../model/model-reslut_critic01-4
# 2021/08/25 15:55:08	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-4.pth
# 2021/08/25 15:55:08	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/25 15:55:08	INFO	Reading training data
# 2021/08/25 15:55:13	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_2338357364975077248.hcpe, a=517.1689515268196
# 2021/08/25 15:55:20	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1158132749111629617.hcpe, a=500.44451957541355
# 2021/08/25 15:55:28	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6904901410362315069.hcpe, a=526.404355363151
# 2021/08/25 15:55:36	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17857036309212935782.hcpe, a=502.2082848723048
# 2021/08/25 15:55:45	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17534187018446256822.hcpe, a=516.4550754621625
# 2021/08/25 15:55:53	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_10287749535006036145.hcpe, a=505.71425627592436
# 2021/08/25 15:56:00	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_13813326514202013036.hcpe, a=500.7749728792819
# 2021/08/25 15:56:08	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_9754989453949195185.hcpe, a=515.536534869022
# 2021/08/25 15:56:17	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_13452186881741650775.hcpe, a=523.8569483717631
# 2021/08/25 15:56:25	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_8644269246287806749.hcpe, a=522.352727771581
# 2021/08/25 15:56:29	INFO	Reading test data
# 2021/08/25 15:56:38	INFO	train position num before preprocessing = 10008474
# 2021/08/25 15:56:38	INFO	train position num = 10008392
# 2021/08/25 15:56:38	INFO	test position num = 2414974
# 2021/08/25 15:57:15	INFO	epoch = 6, steps = 49000, train loss = 2.0791212, 0.2881613, 0.2948957, 2.3693027, test loss = 2.1837339, 0.5721726, 0.6152343, 2.7688251, test accuracy = 0.3769531, 0.6708984
# 2021/08/25 16:01:47	INFO	epoch = 6, steps = 50000, train loss = 2.0722006, 0.2881276, 0.2958181, 2.3626354, test loss = 2.1054182, 0.5791624, 0.6337112, 2.7009454, test accuracy = 0.3769531, 0.6796875
# 2021/08/25 16:06:25	INFO	epoch = 6, steps = 51000, train loss = 2.0723228, 0.2863888, 0.2957311, 2.3615143, test loss = 2.1148672, 0.5401609, 0.6054664, 2.6746197, test accuracy = 0.3681641, 0.6875000
# 2021/08/25 16:11:09	INFO	epoch = 6, steps = 52000, train loss = 2.0697036, 0.2847697, 0.2954017, 2.3576629, test loss = 2.1905413, 0.5578460, 0.6241415, 2.7682760, test accuracy = 0.3535156, 0.6826172
# 2021/08/25 16:15:38	INFO	epoch = 6, steps = 53000, train loss = 2.0642119, 0.2844818, 0.2951030, 2.3518801, test loss = 2.1466537, 0.5503873, 0.6141261, 2.7161627, test accuracy = 0.3750000, 0.6923828
# 2021/08/25 16:20:08	INFO	epoch = 6, steps = 54000, train loss = 2.0623134, 0.2842357, 0.2953549, 2.3498848, test loss = 2.0515735, 0.5466604, 0.6089970, 2.6169348, test accuracy = 0.4091797, 0.7011719
# 2021/08/25 16:24:35	INFO	epoch = 6, steps = 55000, train loss = 2.0582878, 0.2829982, 0.2954171, 2.3450116, test loss = 2.0549569, 0.5786362, 0.6199188, 2.6459780, test accuracy = 0.3886719, 0.6572266
# 2021/08/25 16:29:01	INFO	epoch = 6, steps = 56000, train loss = 2.0571314, 0.2827956, 0.2948426, 2.3435411, test loss = 2.1211007, 0.5401042, 0.5962003, 2.6780336, test accuracy = 0.3496094, 0.7060547
# 2021/08/25 16:33:23	INFO	epoch = 6, steps = 57000, train loss = 2.0471842, 0.2812259, 0.2940976, 2.3322716, test loss = 2.1245389, 0.5538636, 0.6045107, 2.6935964, test accuracy = 0.3681641, 0.6806641
# 2021/08/25 16:37:50	INFO	epoch = 6, steps = 58000, train loss = 2.0506145, 0.2819912, 0.2946311, 2.3363976, test loss = 2.0508890, 0.5647007, 0.6220576, 2.6327965, test accuracy = 0.3681641, 0.6884766
# 2021/08/25 16:45:23	INFO	epoch = 6, steps = 58638, train loss avr = 2.0607396, 0.2839576, 0.2950987, 2.3480396, test loss = 2.0905080, 0.5601830, 0.6164838, 2.6675813, test accuracy = 0.3845714, 0.6801244, test entropy = 1.8768920, 0.5728155
# 2021/08/25 16:45:23	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-5.pth
# 2021/08/25 16:45:24	INFO	Updating batch normalization
# 2021/08/25 17:03:54	INFO	epoch = 6, steps = 58638, swa test loss = 2.0489434, 0.5543398, 0.6092714, 2.6197627, swa test accuracy = 0.3930751, 0.6875112, swa test entropy = 1.8934037, 0.5768842
# 2021/08/25 17:03:54	INFO	Saving the model to ../model/model-reslut_critic01-5
#
# wandb: Waiting for W&B process to finish, PID 37138
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_155500-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_155500-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 2.05061
# wandb:           train/loss_result 0.28199
# wandb:            train/loss_value 0.29463
# wandb:              train/loss_sum 2.3364
# wandb:           valid/loss_policy 2.05089
# wandb:           valid/loss_result 0.5647
# wandb:            valid/loss_value 0.62206
# wandb:              valid/loss_sum 2.6328
# wandb:        valid_acc/acc_policy 0.36816
# wandb:        valid_acc/acc_result 0.68848
# wandb:                    _runtime 4134
# wandb:                  _timestamp 1629878635
# wandb:                       _step 58000
# wandb: Run history:
# wandb:      train/loss_policy █▆▇▆▅▄▃▃▁▂
# wandb:      train/loss_result ██▆▅▄▄▃▃▁▂
# wandb:       train/loss_value ▄██▆▅▆▆▄▁▃
# wandb:         train/loss_sum █▇▇▆▅▄▃▃▁▂
# wandb:      valid/loss_policy █▄▄█▆▁▁▅▅▁
# wandb:      valid/loss_result ▇█▁▄▃▂█▁▃▅
# wandb:       valid/loss_value ▅█▃▆▄▃▅▁▃▆
# wandb:         valid/loss_sum █▅▄█▆▁▂▄▅▂
# wandb:   valid_acc/acc_policy ▄▄▃▁▄█▆▁▃▃
# wandb:   valid_acc/acc_result ▃▄▅▅▆▇▁█▄▅
# wandb:               _runtime ▁▂▂▃▃▄▄▅▅█
# wandb:             _timestamp ▁▂▂▃▃▄▄▅▅█
# wandb:                  _step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 312 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/25 17:04:10	INFO	network resnet10_swish
# 2021/08/25 17:04:10	INFO	batchsize=1024
# 2021/08/25 17:04:10	INFO	lr=0.001
# 2021/08/25 17:04:10	INFO	weight_decay=1e-05
# 2021/08/25 17:04:10	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210825_170425-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/25 17:04:31	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/25 17:04:31	INFO	use amp
# 2021/08/25 17:04:31	INFO	use evalfix
# 2021/08/25 17:04:31	INFO	temperature=1.0
# 2021/08/25 17:04:31	INFO	Loading the model from ../model/model-reslut_critic01-5
# 2021/08/25 17:04:32	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-5.pth
# 2021/08/25 17:04:32	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/25 17:04:32	INFO	Reading training data
# 2021/08/25 17:04:36	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1611184872007260361.hcpe, a=521.5778823074091
# 2021/08/25 17:04:43	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6486704773657753768.hcpe, a=509.67015365682136
# 2021/08/25 17:04:50	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_13018157655023395397.hcpe, a=519.6014943447883
# 2021/08/25 17:04:57	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17529263823531461945.hcpe, a=516.0356335421764
# 2021/08/25 17:05:05	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_8315845241743014461.hcpe, a=513.7095589134522
# 2021/08/25 17:05:12	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_7378380875161994943.hcpe, a=517.7509771055768
# 2021/08/25 17:05:19	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_7412583289295789634.hcpe, a=493.64822359685394
# 2021/08/25 17:05:26	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_4396769361552453229.hcpe, a=502.65749914295634
# 2021/08/25 17:05:34	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_2440216717096502068.hcpe, a=514.709146750036
# 2021/08/25 17:05:42	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_10072626083703473865.hcpe, a=508.50778670432544
# 2021/08/25 17:05:45	INFO	Reading test data
# 2021/08/25 17:05:53	INFO	train position num before preprocessing = 10007625
# 2021/08/25 17:05:53	INFO	train position num = 10007534
# 2021/08/25 17:05:53	INFO	test position num = 2414974
# ...
# 2021/08/26 11:26:19	INFO	Reading test data
# 2021/08/26 11:26:27	INFO	train position num before preprocessing = 10007917
# 2021/08/26 11:26:27	INFO	train position num = 10007816
# 2021/08/26 11:26:27	INFO	test position num = 2414974
# 2021/08/26 11:30:13	INFO	epoch = 22, steps = 206000, train loss = 1.8767328, 0.2756268, 0.2856408, 2.1553637, test loss = 1.9552577, 0.5307268, 0.5998584, 2.5067241, test accuracy = 0.4091797, 0.7041016
# 2021/08/26 11:35:10	INFO	epoch = 22, steps = 207000, train loss = 1.8733874, 0.2746786, 0.2854148, 2.1512869, test loss = 1.8743876, 0.5517001, 0.5960697, 2.4393983, test accuracy = 0.4082031, 0.6855469
# 2021/08/26 11:40:16	INFO	epoch = 22, steps = 208000, train loss = 1.8713555, 0.2726213, 0.2847114, 2.1476038, test loss = 1.9318583, 0.5249386, 0.5978214, 2.4786618, test accuracy = 0.4130859, 0.7294922
# 2021/08/26 11:45:13	INFO	epoch = 22, steps = 209000, train loss = 1.8776490, 0.2730098, 0.2847154, 2.1541705, test loss = 1.9488184, 0.5457245, 0.5889543, 2.5075121, test accuracy = 0.3857422, 0.6953125
# 2021/08/26 11:50:15	INFO	epoch = 22, steps = 210000, train loss = 1.8718962, 0.2725300, 0.2846815, 2.1480717, test loss = 1.9279976, 0.5524130, 0.6034137, 2.4957108, test accuracy = 0.4052734, 0.6757812
# 2021/08/26 11:55:19	INFO	epoch = 22, steps = 211000, train loss = 1.8708189, 0.2716758, 0.2847836, 2.1464270, test loss = 1.9409051, 0.5324533, 0.5992038, 2.4933834, test accuracy = 0.4150391, 0.7060547
# 2021/08/26 12:00:23	INFO	epoch = 22, steps = 212000, train loss = 1.8731029, 0.2717609, 0.2852885, 2.1489221, test loss = 1.9723504, 0.5336102, 0.5901878, 2.5229337, test accuracy = 0.4033203, 0.7050781
# 2021/08/26 12:05:21	INFO	epoch = 22, steps = 213000, train loss = 1.8759156, 0.2713182, 0.2851908, 2.1513955, test loss = 1.8494439, 0.5421627, 0.5921925, 2.4066155, test accuracy = 0.4433594, 0.6933594
# 2021/08/26 12:10:14	INFO	epoch = 22, steps = 214000, train loss = 1.8688670, 0.2704350, 0.2854461, 2.1438053, test loss = 1.9848722, 0.5348777, 0.5944333, 2.5376167, test accuracy = 0.4062500, 0.6933594
# 2021/08/26 12:15:13	INFO	epoch = 22, steps = 215000, train loss = 1.8692219, 0.2703844, 0.2855627, 2.1441598, test loss = 1.9440928, 0.5412647, 0.5971134, 2.5021119, test accuracy = 0.3925781, 0.6923828
# 2021/08/26 12:19:57	INFO	epoch = 22, steps = 215006, train loss avr = 1.8727946, 0.2723257, 0.2851264, 2.1489605, test loss = 1.9383759, 0.5456053, 0.5995676, 2.5001699, test accuracy = 0.4131704, 0.6935491, test entropy = 1.7188574, 0.5768034
# 2021/08/26 12:19:57	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-21.pth
# 2021/08/26 12:19:57	INFO	Updating batch normalization
# 2021/08/26 12:38:49	INFO	epoch = 22, steps = 215006, swa test loss = 1.9045237, 0.5395298, 0.5983352, 2.4616951, swa test accuracy = 0.4192476, 0.7020043, swa test entropy = 1.7305608, 0.5768347
# 2021/08/26 12:38:49	INFO	Saving the model to ../model/model-reslut_critic01-21
#
# wandb: Waiting for W&B process to finish, PID 46065
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210826_112459-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210826_112459-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 1.86922
# wandb:           train/loss_result 0.27038
# wandb:            train/loss_value 0.28556
# wandb:              train/loss_sum 2.14416
# wandb:           valid/loss_policy 1.94409
# wandb:           valid/loss_result 0.54126
# wandb:            valid/loss_value 0.59711
# wandb:              valid/loss_sum 2.50211
# wandb:        valid_acc/acc_policy 0.39258
# wandb:        valid_acc/acc_result 0.69238
# wandb:                    _runtime 4431
# wandb:                  _timestamp 1629949130
# wandb:                       _step 215000
# wandb: Run history:
# wandb:      train/loss_policy ▇▅▃█▃▃▄▇▁▁
# wandb:      train/loss_result █▇▄▅▄▃▃▂▁▁
# wandb:       train/loss_value █▆▁▁▁▂▅▅▇▇
# wandb:         train/loss_sum █▆▃▇▄▃▄▆▁▁
# wandb:      valid/loss_policy ▆▂▅▆▅▆▇▁█▆
# wandb:      valid/loss_result ▂█▁▆█▃▃▅▄▅
# wandb:       valid/loss_value ▆▄▅▁█▆▂▃▄▅
# wandb:         valid/loss_sum ▆▃▅▆▆▆▇▁█▆
# wandb:   valid_acc/acc_policy ▄▄▄▁▃▅▃█▃▂
# wandb:   valid_acc/acc_result ▅▂█▄▁▅▅▃▃▃
# wandb:               _runtime ▁▂▂▃▃▄▄▅▅█
# wandb:             _timestamp ▁▂▂▃▃▄▄▅▅█
# wandb:                  _step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 309 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/26 12:39:07	INFO	network resnet10_swish
# 2021/08/26 12:39:07	INFO	batchsize=1024
# 2021/08/26 12:39:07	INFO	lr=0.001
# 2021/08/26 12:39:07	INFO	weight_decay=1e-05
# 2021/08/26 12:39:07	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210826_123922-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/26 12:39:29	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/26 12:39:29	INFO	use amp
# 2021/08/26 12:39:29	INFO	use evalfix
# 2021/08/26 12:39:29	INFO	temperature=1.0
# 2021/08/26 12:39:29	INFO	Loading the model from ../model/model-reslut_critic01-21
# 2021/08/26 12:39:30	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-21.pth
# 2021/08/26 12:39:30	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/26 12:39:30	INFO	Reading training data
# 2021/08/26 12:39:34	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1390657711351513515.hcpe, a=518.9241657869944
# 2021/08/26 12:39:41	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_7303221119206032815.hcpe, a=526.3543147067224
# 2021/08/26 12:39:49	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_906035764097677269.hcpe, a=506.6724316005084
# 2021/08/26 12:39:55	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_2504993141413804735.hcpe, a=513.3907701776023
# 2021/08/26 12:40:03	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_4014852895365312890.hcpe, a=514.8168177298704
# 2021/08/26 12:40:10	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6249452036068591471.hcpe, a=491.42404623213673
# 2021/08/26 12:40:16	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_3558691252376088865.hcpe, a=504.22140127241494
# 2021/08/26 12:40:23	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_9764535531684762238.hcpe, a=502.52833339722434
# 2021/08/26 12:40:31	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_14738721350812666690.hcpe, a=523.552912558415
# 2021/08/26 12:40:38	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_6862654340373192875.hcpe, a=487.3828282387876
# 2021/08/26 12:40:42	INFO	Reading test data
# 2021/08/26 12:40:49	INFO	train position num before preprocessing = 10008209
# 2021/08/26 12:40:49	INFO	train position num = 10008106
# 2021/08/26 12:40:49	INFO	test position num = 2414974
# 2021/08/26 12:45:44	INFO	epoch = 23, steps = 216000, train loss = 1.8680702, 0.2763856, 0.2865117, 2.1474936, test loss = 1.9043391, 0.5394163, 0.6142067, 2.4661925, test accuracy = 0.4189453, 0.6835938
# 2021/08/26 12:50:44	INFO	epoch = 23, steps = 217000, train loss = 1.8678219, 0.2754509, 0.2865829, 2.1466124, test loss = 1.9523075, 0.5503209, 0.5927985, 2.5153716, test accuracy = 0.4003906, 0.6699219
# 2021/08/26 12:55:45	INFO	epoch = 23, steps = 218000, train loss = 1.8700880, 0.2740992, 0.2862906, 2.1478446, test loss = 1.8829143, 0.5583783, 0.6094542, 2.4566154, test accuracy = 0.4169922, 0.6728516
# 2021/08/26 13:00:59	INFO	epoch = 23, steps = 219000, train loss = 1.8671217, 0.2740168, 0.2860789, 2.1447571, test loss = 1.9282254, 0.5549545, 0.6114683, 2.5001340, test accuracy = 0.4296875, 0.6777344
# 2021/08/26 13:06:12	INFO	epoch = 23, steps = 220000, train loss = 1.8677307, 0.2733266, 0.2861722, 2.1449110, test loss = 1.8833182, 0.5489430, 0.6061062, 2.4494100, test accuracy = 0.4355469, 0.7001953
# 2021/08/26 13:11:18	INFO	epoch = 23, steps = 221000, train loss = 1.8669635, 0.2724391, 0.2861917, 2.1435283, test loss = 1.9008434, 0.5398753, 0.5934416, 2.4567885, test accuracy = 0.4052734, 0.7001953
# 2021/08/26 13:16:25	INFO	epoch = 23, steps = 222000, train loss = 1.8614394, 0.2717229, 0.2857382, 2.1373669, test loss = 1.9223170, 0.5498577, 0.6058609, 2.4889758, test accuracy = 0.4179688, 0.6875000
# 2021/08/26 13:21:34	INFO	epoch = 23, steps = 223000, train loss = 1.8639968, 0.2721852, 0.2861268, 2.1403645, test loss = 2.0585725, 0.5019473, 0.5786442, 2.5835288, test accuracy = 0.3896484, 0.7460938
# 2021/08/26 13:26:39	INFO	epoch = 23, steps = 224000, train loss = 1.8628701, 0.2715542, 0.2858814, 2.1387224, test loss = 2.0168996, 0.5308604, 0.5975366, 2.5677629, test accuracy = 0.3964844, 0.7109375
# 2021/08/26 13:35:27	INFO	epoch = 23, steps = 224779, train loss avr = 1.8660386, 0.2732781, 0.2861940, 2.1431915, test loss = 1.9345572, 0.5463126, 0.5994249, 2.4968036, test accuracy = 0.4117275, 0.6924516, test entropy = 1.7642142, 0.5761011
# 2021/08/26 13:35:27	INFO	Saving the checkpoint to ../model/checkpoint-reslut_critic01-22.pth
# 2021/08/26 13:35:28	INFO	Updating batch normalization
# 2021/08/26 13:54:56	INFO	epoch = 23, steps = 224779, swa test loss = 1.8996784, 0.5392215, 0.5974704, 2.4563745, swa test accuracy = 0.4197131, 0.7019919, swa test entropy = 1.7267830, 0.5773046
# 2021/08/26 13:54:56	INFO	Saving the model to ../model/model-reslut_critic01-22
#
# wandb: Waiting for W&B process to finish, PID 46627
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210826_123922-reslut_critic01.1629853076.776472/logs/debug.log
# wandb: Find internal logs for this run at: /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210826_123922-reslut_critic01.1629853076.776472/logs/debug-internal.log
# wandb: Run summary:
# wandb:           train/loss_policy 1.86287
# wandb:           train/loss_result 0.27155
# wandb:            train/loss_value 0.28588
# wandb:              train/loss_sum 2.13872
# wandb:           valid/loss_policy 2.0169
# wandb:           valid/loss_result 0.53086
# wandb:            valid/loss_value 0.59754
# wandb:              valid/loss_sum 2.56776
# wandb:        valid_acc/acc_policy 0.39648
# wandb:        valid_acc/acc_result 0.71094
# wandb:                    _runtime 4535
# wandb:                  _timestamp 1629953697
# wandb:                       _step 224000
# wandb: Run history:
# wandb:      train/loss_policy ▆▆█▆▆▅▁▃▂
# wandb:      train/loss_result █▇▅▅▄▂▁▂▁
# wandb:       train/loss_value ▇█▆▄▅▅▁▄▂
# wandb:         train/loss_sum █▇█▆▆▅▁▃▂
# wandb:      valid/loss_policy ▂▄▁▃▁▂▃█▆
# wandb:      valid/loss_result ▆▇██▇▆▇▁▅
# wandb:       valid/loss_value █▄▇▇▆▄▆▁▅
# wandb:         valid/loss_sum ▂▄▁▄▁▁▃█▇
# wandb:   valid_acc/acc_policy ▅▃▅▇█▃▅▁▂
# wandb:   valid_acc/acc_result ▂▁▁▂▄▄▃█▅
# wandb:               _runtime ▁▂▂▃▃▄▄▅█
# wandb:             _timestamp ▁▂▂▃▃▄▄▅█
# wandb:                  _step ▁▂▃▄▅▅▆▇█
# wandb:
# wandb: Synced 6 W&B file(s), 0 media file(s), 280 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced reslut_critic01: https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# 2021/08/26 13:55:14	INFO	network resnet10_swish
# 2021/08/26 13:55:14	INFO	batchsize=1024
# 2021/08/26 13:55:14	INFO	lr=0.001
# 2021/08/26 13:55:14	INFO	weight_decay=1e-05
# 2021/08/26 13:55:14	INFO	val_lambda=0.3
# wandb: Currently logged in as: hmatsuya (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.11.2
# wandb: Syncing run reslut_critic01
# wandb:  View project at https://wandb.ai/hmatsuya/test_critic
# wandb:  View run at https://wandb.ai/hmatsuya/test_critic/runs/reslut_critic01.1629853076.776472
# wandb: Run data is saved locally in /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/wandb/run-20210826_135530-reslut_critic01.1629853076.776472
# wandb: Run `wandb offline` to turn off syncing.
#
# 2021/08/26 13:55:36	INFO	use swa(swa_start_epoch=1, swa_freq=250, swa_n_avr=10)
# 2021/08/26 13:55:36	INFO	use amp
# 2021/08/26 13:55:36	INFO	use evalfix
# 2021/08/26 13:55:36	INFO	temperature=1.0
# 2021/08/26 13:55:36	INFO	Loading the model from ../model/model-reslut_critic01-22
# 2021/08/26 13:55:37	INFO	Loading the checkpoint from ../model/checkpoint-reslut_critic01-22.pth
# 2021/08/26 13:55:37	INFO	optimizer SGD (Parameter Group 0 dampening: 0 lr: 0.001 momentum: 0.9 nesterov: True weight_decay: 1e-05)
# 2021/08/26 13:55:37	INFO	Reading training data
# 2021/08/26 13:55:42	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_16122263895847606627.hcpe, a=511.71018880970735
# 2021/08/26 13:55:48	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_15424406625704946447.hcpe, a=507.3860491951166
# 2021/08/26 13:55:56	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_4146436645797209819.hcpe, a=522.5647677973079
# 2021/08/26 13:56:02	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_696015611628691475.hcpe, a=504.1950094047305
# 2021/08/26 13:56:10	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_9948222605137982390.hcpe, a=514.087334475006
# 2021/08/26 13:56:17	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1419806022234951870.hcpe, a=523.191245622048
# 2021/08/26 13:56:24	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_1939100043922765432.hcpe, a=502.95604007700655
# 2021/08/26 13:56:30	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_17765629041833799116.hcpe, a=519.8903112391198
# 2021/08/26 13:56:38	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_9031139950243523697.hcpe, a=490.68166513126226
# 2021/08/26 13:56:46	INFO	/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled/out_16669533294815646840.hcpe, a=494.7798644284322
# 2021/08/26 13:56:49	INFO	Reading test data
# 2021/08/26 13:56:57	INFO	train position num before preprocessing = 10008657
# 2021/08/26 13:56:57	INFO	train position num = 10008571
# 2021/08/26 13:56:57	INFO	test position num = 2414974
# 2021/08/26 13:58:04	INFO	epoch = 24, steps = 225000, train loss = 1.8692287, 0.2748255, 0.2851550, 2.1471531, test loss = 1.8927855, 0.5383307, 0.5902159, 2.4466817, test accuracy = 0.4042969, 0.6806641
# 2021/08/26 14:03:09	INFO	epoch = 24, steps = 226000, train loss = 1.8628227, 0.2735826, 0.2845153, 2.1396851, test loss = 1.9400480, 0.5352600, 0.5991758, 2.4944825, test accuracy = 0.4072266, 0.6933594
# 2021/08/26 14:08:14	INFO	epoch = 24, steps = 227000, train loss = 1.8692011, 0.2726672, 0.2843950, 2.1453866, test loss = 1.8881785, 0.5531436, 0.6028698, 2.4562397, test accuracy = 0.4130859, 0.6845703
# 2021/08/26 14:13:19	INFO	epoch = 24, steps = 228000, train loss = 1.8631533, 0.2721836, 0.2845658, 2.1390515, test loss = 1.9233949, 0.5390626, 0.6046770, 2.4821417, test accuracy = 0.4199219, 0.6943359

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/hmats/workspace/DeepLearningShogi/notebook'

# %%
test_name = "result_critic01"
name = f'{test_name}'
model=f'../model/model-{name}-15'

# Convert to ONNX
! python ../dlshogi/convert_model_to_onnx.py --network resnet10_swish ../model/{model} ../model/{model}.onnx
! scp ../model/{model}.onnx corgi:/home/hmatsuya/workspace/Shogi/dlcobra/model/
# Out:
# graph(%input1 : Float(1:5022, 62:81, 9:9, 9:1, requires_grad=0, device=cuda:0),
#       %input2 : Float(1:4617, 57:81, 9:9, 9:1, requires_grad=0, device=cuda:0),
#       %l1_1_1.weight : Float(192:558, 62:9, 3:3, 3:1, requires_grad=1, device=cuda:0),
#       %l1_1_2.weight : Float(192:62, 62:1, 1:1, 1:1, requires_grad=1, device=cuda:0),
#       %l1_2.weight : Float(192:57, 57:1, 1:1, 1:1, requires_grad=1, device=cuda:0),
#       %l22.weight : Float(27:192, 192:1, 1:1, 1:1, requires_grad=1, device=cuda:0),
#       %l22_2.bias : Float(2187:1, requires_grad=1, device=cuda:0),
#       %l23_v.weight : Float(256:2187, 2187:1, requires_grad=1, device=cuda:0),
#       %l23_v.bias : Float(256:1, requires_grad=1, device=cuda:0),
#       %l24_v.weight : Float(1:256, 256:1, requires_grad=1, device=cuda:0),
#       %l24_v.bias : Float(1:1, requires_grad=1, device=cuda:0),
#       %norm1.weight : Float(192:1, requires_grad=1, device=cuda:0),
#       %norm1.bias : Float(192:1, requires_grad=1, device=cuda:0),
#       %norm1.running_mean : Float(192:1, requires_grad=0, device=cuda:0),
#       %norm1.running_var : Float(192:1, requires_grad=0, device=cuda:0),
#       %254 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %255 : Float(192:1, requires_grad=0, device=cuda:0),
#       %257 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %258 : Float(192:1, requires_grad=0, device=cuda:0),
#       %260 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %261 : Float(192:1, requires_grad=0, device=cuda:0),
#       %263 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %264 : Float(192:1, requires_grad=0, device=cuda:0),
#       %266 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %267 : Float(192:1, requires_grad=0, device=cuda:0),
#       %269 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %270 : Float(192:1, requires_grad=0, device=cuda:0),
#       %272 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %273 : Float(192:1, requires_grad=0, device=cuda:0),
#       %275 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %276 : Float(192:1, requires_grad=0, device=cuda:0),
#       %278 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %279 : Float(192:1, requires_grad=0, device=cuda:0),
#       %281 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %282 : Float(192:1, requires_grad=0, device=cuda:0),
#       %284 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %285 : Float(192:1, requires_grad=0, device=cuda:0),
#       %287 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %288 : Float(192:1, requires_grad=0, device=cuda:0),
#       %290 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %291 : Float(192:1, requires_grad=0, device=cuda:0),
#       %293 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %294 : Float(192:1, requires_grad=0, device=cuda:0),
#       %296 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %297 : Float(192:1, requires_grad=0, device=cuda:0),
#       %299 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %300 : Float(192:1, requires_grad=0, device=cuda:0),
#       %302 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %303 : Float(192:1, requires_grad=0, device=cuda:0),
#       %305 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %306 : Float(192:1, requires_grad=0, device=cuda:0),
#       %308 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %309 : Float(192:1, requires_grad=0, device=cuda:0),
#       %311 : Float(192:1728, 192:9, 3:3, 3:1, requires_grad=0, device=cuda:0),
#       %312 : Float(192:1, requires_grad=0, device=cuda:0),
#       %314 : Float(27:192, 192:1, 1:1, 1:1, requires_grad=0, device=cuda:0),
#       %315 : Float(27:1, requires_grad=0, device=cuda:0)):
#   %142 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%input1, %l1_1_1.weight) # /home/hmatsuya/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py:419:0
#   %143 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input1, %l1_1_2.weight) # /home/hmatsuya/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py:419:0
#   %144 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%input2, %l1_2.weight) # /home/hmatsuya/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py:419:0
#   %145 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%142, %143) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:86:0
#   %146 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%145, %144) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:86:0
#   %147 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%146, %norm1.weight, %norm1.bias, %norm1.running_mean, %norm1.running_var) # /home/hmatsuya/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:2056:0
#   %148 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%147) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %149 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%147, %148) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %253 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %254, %255)
#   %152 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%253) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %153 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%253, %152) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %256 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%153, %257, %258)
#   %156 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%256, %149) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:90:0
#   %157 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%156) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %158 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%156, %157) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %259 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%158, %260, %261)
#   %161 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%259) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %162 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%259, %161) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %262 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%162, %263, %264)
#   %165 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%262, %158) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:94:0
#   %166 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%165) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %167 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%165, %166) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %265 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%167, %266, %267)
#   %170 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%265) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %171 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%265, %170) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %268 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%171, %269, %270)
#   %174 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%268, %167) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:98:0
#   %175 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%174) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %176 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%174, %175) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %271 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%176, %272, %273)
#   %179 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%271) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %180 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%271, %179) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %274 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%180, %275, %276)
#   %183 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%274, %176) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:102:0
#   %184 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%183) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %185 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%183, %184) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %277 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%185, %278, %279)
#   %188 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%277) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %189 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%277, %188) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %280 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%189, %281, %282)
#   %192 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%280, %185) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:106:0
#   %193 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%192) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %194 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%192, %193) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %283 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%194, %284, %285)
#   %197 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%283) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %198 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%283, %197) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %286 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%198, %287, %288)
#   %201 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%286, %194) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:110:0
#   %202 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%201) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %203 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%201, %202) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %289 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%203, %290, %291)
#   %206 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%289) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %207 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%289, %206) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %292 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%207, %293, %294)
#   %210 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%292, %203) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:114:0
#   %211 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%210) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %212 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%210, %211) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %295 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%212, %296, %297)
#   %215 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%295) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %216 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%295, %215) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %298 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%216, %299, %300)
#   %219 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%298, %212) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:118:0
#   %220 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%219) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %221 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%219, %220) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %301 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%221, %302, %303)
#   %224 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%301) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %225 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%301, %224) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %304 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%225, %305, %306)
#   %228 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%304, %221) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:122:0
#   %229 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%228) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %230 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%228, %229) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %307 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%230, %308, %309)
#   %233 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%307) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %234 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%307, %233) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %310 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%234, %311, %312)
#   %237 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Add(%310, %230) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:126:0
#   %238 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%237) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %239 : Float(1:15552, 192:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%237, %238) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %240 : Float(1:2187, 27:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%239, %l22.weight) # /home/hmatsuya/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py:419:0
#   %241 : Float(1:2187, 2187:1, requires_grad=1, device=cuda:0) = onnx::Flatten[axis=1](%240) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:129:0
#   %output_policy : Float(1:2187, 2187:1, requires_grad=1, device=cuda:0) = onnx::Add(%241, %l22_2.bias) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:13:0
#   %313 : Float(1:2187, 27:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%239, %314, %315)
#   %245 : Float(1:2187, 27:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%313) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %246 : Float(1:2187, 27:81, 9:9, 9:1, requires_grad=1, device=cuda:0) = onnx::Mul(%313, %245) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %247 : Float(1:2187, 2187:1, requires_grad=1, device=cuda:0) = onnx::Flatten[axis=1](%246) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:132:0
#   %248 : Float(1:256, 256:1, requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1](%247, %l23_v.weight, %l23_v.bias) # /home/hmatsuya/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:1690:0
#   %249 : Float(1:256, 256:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%248) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %250 : Float(1:256, 256:1, requires_grad=1, device=cuda:0) = onnx::Mul(%248, %249) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network_resnet10_swish.py:18:0
#   %251 : Float(1:1, 1:1, requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1](%250, %l24_v.weight, %l24_v.bias) # /home/hmatsuya/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:1690:0
#   %output_value : Float(1:1, 1:1, requires_grad=1, device=cuda:0) = onnx::Sigmoid(%251) # /mnt/c/Users/hmats/workspace/DeepLearningShogi/dlshogi/network/policy_value_network.py:31:0
#   return (%output_policy, %output_value)
#
# model-reslut_critic01-15.onnx                 100%   28MB  11.2MB/s   00:02
