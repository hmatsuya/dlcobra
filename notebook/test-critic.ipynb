# %%
# !nvidia-smi
# Out:
# Wed Aug 18 20:48:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 471.41       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:4B:00.0  On |                  N/A |
# |  0%   37C    P8    40W / 300W |   1632MiB / 11264MiB |    ERR!      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# /bin/bash: nvcc: command not found

# %%
import os
import random
from datetime import datetime
import time

# %%
os.chdir('..')
# os.chdir('..')

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/hmats/workspace/DeepLearningShogi'

# %%
# pip install -e .

# %%
# os.listdir('//corgi/hmatsuya/workspace/Shogi/data/dl_data/hcpe')
# os.listdir('/mnt/corgi/hmatsuya/workspace/Shogi/data/dl_data/hcpe')

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/hmats/workspace/DeepLearningShogi'

# %%
os.chdir('dlshogi')

# %%
#os.mkdir('../model')

# %%
#os.mkdir('../log')

# %% [markdown]
# ## Test critic

# %%
# resnet8_dropout
# # advantage: no value
# val_lambda: 0
# tanh
# polic_coef: 0.5

chunk_size = 38 * 20 * 1000 * 1000
activation='C:\\Anaconda3\\Scripts\\activate.bat'
test='/mnt/corgi/hmatsuya/workspace/Shogi/data/dl_data/hcpe/floodgate_teacher_uniq-test-01'

#! wsl ssh hmatsuya@corgi ls -lh /home/hmatsuya/workspace/Shogi/data/apery_teacher/

# resume = '-r ../model/state-2019'
resume = ''
teacher_dir = '/mnt/corgi/hmatsuya/workspace/Shogi/data/apery_teacher/shuffled'
filelist = os.listdir(teacher_dir)
hcpelist = list(filter(lambda f: '.hcpe' in f, filelist))
files = []
project = "test_critic"
test_name = "no_critic"
name = f'{test_name}'
run_id = f'{name}.{time.time()}'
i = 0
if i == 0:
    resume = ''
else:
    resume = f'-m ../model/model-{name}-{i-1} -r ../model/checkpoint-{name}-{i-1}.pth'

for file in random.sample(hcpelist, len(hcpelist)):
    
    files.append(file)
    if len(files) < 10:
        continue
    
    teacher=' '.join([f'{teacher_dir}/{f}' for f in files])
    
    model=f'../model/model-{name}-{i}'
    checkpoint=f'../model/checkpoint-{name}-{i}.pth'
    log=f'../log/{name}.txt'
    ! python -u train.py {teacher} {test} --model {model} --checkpoint {checkpoint} {resume} --val_lambda 0.3 --lr 0.001 --weight_decay 0.00001 --use_average --use_evalfix --use_swa --log {log} --use_amp --project {project} --run_id {run_id}

    files.clear()
    resume = f'-r {checkpoint} -m {model}'
    i += 1
    
    break
# Out:
# ^C
# Traceback (most recent call last):
#   File "train.py", line 22, in <module>
#     import wandb
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/__init__.py", line 38, in <module>
#     from wandb import sdk as wandb_sdk
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/sdk/__init__.py", line 9, in <module>
#     from .wandb_artifacts import Artifact  # noqa: F401
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/sdk/wandb_artifacts.py", line 15, in <module>
#     from wandb.apis import InternalApi, PublicApi
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/apis/__init__.py", line 32, in <module>
#     from .internal import Api as InternalApi  # noqa
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/apis/internal.py", line 7, in <module>
#     from wandb.sdk.internal.internal_api import Api as InternalApi
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/sdk/internal/internal_api.py", line 2, in <module>
#     from gql import Client, gql  # type: ignore
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/vendor/gql-0.2.0/gql/__init__.py", line 1, in <module>
#     from .gql import gql
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/vendor/gql-0.2.0/gql/gql.py", line 2, in <module>
#     from graphql.language.parser import parse
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/vendor/graphql-core-1.1/graphql/__init__.py", line 43, in <module>
#     from .graphql import (
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/vendor/graphql-core-1.1/graphql/graphql.py", line 5, in <module>
#     from .validation import validate
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/vendor/graphql-core-1.1/graphql/validation/__init__.py", line 1, in <module>
#     from .validation import validate
#   File "/home/hmatsuya/anaconda3/lib/python3.8/site-packages/wandb/vendor/graphql-core-1.1/graphql/validation/validation.py", line 5, in <module>
#     from ..utils.type_info import TypeInfo
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 844, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 939, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1038, in get_data
# KeyboardInterrupt
