# %%
import sys
sys.path.insert(1, '../utils')

# %%
#!pip install cshogi

# %%
from importlib import reload  
import matches2
reload(matches2)
# Out:
# ../utils\matches2.py:194: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(board.is_pseudo_legal(board.move_from_usi(move_usi)), "ERROR: Illegal move: " + move_usi)
# <module 'matches2' from '../utils\\matches2.py'>

# %%
activation='C:\\Anaconda3\\Scripts\\activate.bat'

for i in range(0, 1):

    arglist = [
        "../x64/Release/dlshogi_tensorrt.exe",
#         r'C:\Windows\System32\wsl.exe /home/hmatsuya/anaconda3/bin/python3 ensemble.py',
        "../utils/ensemble_cobra.bat",
        "--options1", "DNN_Model:model.onnx",
#         "--options2", f"DNN_Model:../../model/model-selfplay-399_{i}.onnx",
        "--games", "1",
        "--byoyomi", "1",
        "--max_turn", "256",
        "--initial_positions", "../../ShogiGokakuKyokumen/2020年/floodgate2020（R4000以上）/互角局面集/互角局面集（030手目、評価値±100以内、547局面）.sfen",
    #    "initial_positions": "",
    #    "kifu_dir": "",
    #    "log": "",
    #    "debug": "",
    ]
    match_args = matches2.parse_arguments(arglist)
    winrate = matches2.matches(match_args)
#     wandb.log({"i": i, "winrate": winrate})
    print(f"{i}: {winrate} ({datetime.now()})", flush=True)
# Out:
# ../utils
# <subprocess.Popen object at 0x00000217703D6760>
# <_io.BufferedWriter name=10>
# usiok
# <subprocess.Popen object at 0x00000217703D6730>
# <_io.BufferedWriter name=13>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-988fe00f3cd5> in <module>
#      19     ]
#      20     match_args = matches2.parse_arguments(arglist)
# ---> 21     winrate = matches2.matches(match_args)
#      22 #     wandb.log({"i": i, "winrate": winrate})
#      23     print(f"{i}: {winrate} ({datetime.now()})", flush=True)
#
# ~\workspace\DeepLearningShogi\utils\matches2.py in matches(args)
#      88             print(p)
#      89             print(p.stdin)
# ---> 90             p.stdin.flush()
#      91
#      92             while True:
#
# OSError: [Errno 22] Invalid argument
